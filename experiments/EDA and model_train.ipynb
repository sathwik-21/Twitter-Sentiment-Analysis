# %%
import pandas as pd

# %%
df=pd.read_csv('Data/twitter_training.csv',header=None,names=['index','borderlands','sentiment','tweet'])

# %%
df.head()
# Out:
#    index  borderlands sentiment  \
# 0   2401  Borderlands  Positive
# 1   2401  Borderlands  Positive
# 2   2401  Borderlands  Positive
# 3   2401  Borderlands  Positive
# 4   2401  Borderlands  Positive
#
#                                                tweet
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
df.drop(columns=['index','borderlands'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   sentiment                                              tweet
# 0  Positive  im getting on borderlands and i will murder yo...
# 1  Positive  I am coming to the borders and I will kill you...
# 2  Positive  im getting on borderlands and i will kill you ...
# 3  Positive  im coming on borderlands and i will murder you...
# 4  Positive  im getting on borderlands 2 and i will murder ...

# %%
df.shape
# Out:
# (74682, 2)

# %%
df.isna().count
# Out:
# <bound method DataFrame.count of        sentiment  tweet
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False
# ...          ...    ...
# 74677      False  False
# 74678      False  False
# 74679      False  False
# 74680      False  False
# 74681      False  False
#
# [74682 rows x 2 columns]>

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 74677    False
# 74678    False
# 74679    False
# 74680    False
# 74681    False
# Length: 74682, dtype: bool

# %%
#Preprocessing the tweets

# %% [markdown]
# 1. Lowercasing

# %%
df['tweet']=df['tweet'].str.lower()

# %%
df['tweet']
# Out:
# 0        im getting on borderlands and i will murder yo...
# 1        i am coming to the borders and i will kill you...
# 2        im getting on borderlands and i will kill you ...
# 3        im coming on borderlands and i will murder you...
# 4        im getting on borderlands 2 and i will murder ...
#                                ...
# 74677    just realized that the windows partition of my...
# 74678    just realized that my mac window partition is ...
# 74679    just realized the windows partition of my mac ...
# 74680    just realized between the windows partition of...
# 74681    just like the windows partition of my mac is l...
# Name: tweet, Length: 74682, dtype: object

# %%
df.dropna(inplace=True)

# %% [markdown]
# 2. Remove Punctuation

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude=string.punctuation

# %%
def remove_punc(text):
    return text.translate(str.maketrans('','',exclude))

# %%
df['tweet']=df['tweet'].apply(remove_punc)

# %% [markdown]
# Model Training

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Input

# %%
tokenizer=Tokenizer(oov_token="<OOV>")

# %%
tokenizer.fit_on_texts(df['tweet'])

# %%
len(tokenizer.word_index)
# Out:
# 42552

# %%
word_counts=tokenizer.word_counts

# %%
word_counts
# Out:
# OrderedDict([('im', 3828),
#              ('getting', 1280),
#              ('on', 12050),
#              ('borderlands', 1542),
#              ('and', 26579),
#              ('i', 29178),
#              ('will', 3312),
#              ('murder', 81),
#              ('you', 12154),
#              ('all', 5547),
#              ('am', 1765),
#              ('coming', 485),
#              ('to', 28825),
#              ('the', 44419),
#              ('borders', 12),
#              ('kill', 440),
#              ('2', 4055),
#              ('me', 6988),
#              ('into', 1177),
#              ('can', 3476),
#              ('so', 7795),
#              ('spent', 189),
#              ('a', 24095),
#              ('few', 539),
#              ('hours', 576),
#              ('making', 630),
#              ('something', 943),
#              ('for', 15595),
#              ('fun', 1574),
#              ('if', 3648),
#              ('dont', 2148),
#              ('know', 1745),
#              ('huge', 418),
#              ('fan', 324),
#              ('maya', 24),
#              ('is', 17823),
#              ('one', 3579),
#              ('of', 19438),
#              ('my', 11841),
#              ('favorite', 633),
#              ('characters', 228),
#              ('decided', 221),
#              ('make', 1671),
#              ('myself', 377),
#              ('wallpaper', 14),
#              ('pc', 771),
#              ('here', 1549),
#              ('original', 231),
#              ('image', 72),
#              ('versus', 18),
#              ('creation', 7),
#              ('made', 1047),
#              ('enjoy', 465),
#              ('pictwittercommlsi5wf9jg', 3),
#              ('couple', 159),
#              ('doing', 742),
#              ('that', 10227),
#              ('heres', 155),
#              ('picture', 118),
#              ('compared', 79),
#              ('have', 6682),
#              ('pictwittercom', 871),
#              ('mlsi5wf9jg', 1),
#              ('rhandlerr', 1982),
#              ('2010', 65),
#              ('was', 5425),
#              ('rockhard', 4),
#              ('la', 69),
#              ('varlope', 4),
#              ('rare', 34),
#              ('powerful', 180),
#              ('handsome', 73),
#              ('jackpot', 7),
#              ('3', 2582),
#              ('xbox', 2107),
#              ('dlvritrmtrgf', 3),
#              ('dlvrit', 64),
#              ('rmtrgf', 3),
#              ('dfrit', 7),
#              ('vita', 12),
#              ('but', 6345),
#              ('1', 1869),
#              ('live', 1156),
#              ('rock', 77),
#              ('hard', 565),
#              ('music', 377),
#              ('sega', 27),
#              ('dlvr', 66),
#              ('from', 4389),
#              ('it', 13775),
#              ('e', 332),
#              ('ihard', 1),
#              ('like', 4878),
#              ('london', 25),
#              ('de', 106),
#              ('2011', 52),
#              ('first', 1730),
#              ('session', 82),
#              ('in', 15385),
#              ('long', 670),
#              ('time', 2944),
#              ('where', 733),
#              ('actually', 1102),
#              ('had', 2003),
#              ('really', 3260),
#              ('satisfying', 48),
#              ('combat', 64),
#              ('experience', 342),
#              ('got', 2311),
#              ('some', 2885),
#              ('good', 3548),
#              ('kills', 226),
#              ('this', 14652),
#              ('fighting', 73),
#              ('enjoyed', 196),
#              ('rather', 143),
#              ('real', 684),
#              ('nice', 891),
#              ('wait', 1337),
#              ('hot', 235),
#              ('row', 157),
#              ('bad', 1458),
#              ('did', 1123),
#              ('biggest', 230),
#              ('dissappoinment', 4),
#              ('life', 815),
#              ('came', 342),
#              ('out', 4480),
#              ('year', 1227),
#              ('ago', 386),
#              ('fuck', 2032),
#              ('disappointment', 74),
#              ('male', 20),
#              ('hanging', 74),
#              ('back', 1906),
#              ('last', 1267),
#              ('we', 3906),
#              ('finished', 317),
#              ('finally', 889),
#              ('yas', 10),
#              ('thank', 1422),
#              ('everyone', 1076),
#              ('try', 577),
#              ('stream', 933),
#              ('tomorrow', 354),
#              ('not', 6313),
#              ('might', 372),
#              ('irl', 53),
#              ('streams', 85),
#              ('while', 955),
#              ('awayu', 4),
#              ('shall', 41),
#              ('see', 2769),
#              ('much', 1879),
#              ('raids', 29),
#              ('mompoumumpow', 4),
#              ('megamagwitch', 4),
#              ('kfdmitch', 3),
#              ('find', 558),
#              ('yes', 350),
#              ('ill', 460),
#              ('maybe', 487),
#              ('well', 1241),
#              ('thanks', 1342),
#              ('mompou', 2),
#              ('mumpow', 2),
#              ('up', 3143),
#              ('get', 3941),
#              ('haircut', 8),
#              ('wasnt', 129),
#              ('would', 1764),
#              ('still', 2450),
#              ('be', 6043),
#              ('hawaii', 4),
#              ('megamagwife', 1),
#              ('fendmitch', 1),
#              ('update', 803),
#              ('guys', 1179),
#              ('even', 2232),
#              ('go', 2043),
#              ('hope', 577),
#              ('10', 972),
#              ('never', 1413),
#              ('both', 648),
#              ('or', 2853),
#              ('4', 1847),
#              ('hey', 636),
#              ('use', 691),
#              ('how', 2918),
#              ('many', 899),
#              ('their', 1858),
#              ('man', 1105),
#              ('gearbox', 32),
#              ('needs', 334),
#              ('fix', 1474),
#              ('dissapointing', 3),
#              ('drops', 112),
#              ('new', 3208),
#              ('dlc', 165),
#              ('cant', 2184),
#              ('fine', 165),
#              ('farm', 31),
#              ('bosses', 18),
#              ('mayhem', 65),
#              ('legendary', 131),
#              ('drop', 219),
#              ('anywhere', 120),
#              ('else', 353),
#              ('610', 7),
#              ('sucks', 302),
#              ('alot', 45),
#              ('these', 1665),
#              ('disappointing', 95),
#              ('elsewhere', 13),
#              ('disssapointing', 1),
#              ('bethesda', 32),
#              ('completely', 311),
#              ('days', 729),
#              ('having', 753),
#              ('foot', 38),
#              ('6', 630),
#              ('unk', 1467),
#              ('force', 113),
#              ('check', 773),
#              ('epic', 418),
#              ('streamer', 106),
#              ('watch', 1097),
#              ('striptease', 2),
#              ('our', 1844),
#              ('big', 996),
#              ('checkunk', 6),
#              ('blaming', 13),
#              ('sight', 32),
#              ('tardiness', 3),
#              ('little', 607),
#              ('bit', 412),
#              ('called', 318),
#              ('early', 258),
#              ('work', 1231),
#              ('sorry', 417),
#              ('loves', 81),
#              ('twitchtvpunnisenpai', 3),
#              ('borderland', 14),
#              ('morning', 367),
#              ('catch', 78),
#              ('love', 3239),
#              ('twitchtv', 317),
#              ('punnisenpai', 1),
#              ('guilty', 41),
#              ('sobriety', 1),
#              ('borderline', 9),
#              ('why', 2813),
#              ('does', 727),
#              ('every', 1319),
#              ('slicked', 4),
#              ('hair', 118),
#              ('haven’t', 97),
#              ('heard', 180),
#              ('bangs', 5),
#              ('stupid', 595),
#              ('assholes', 51),
#              ('border', 48),
#              ('countries', 34),
#              ('your', 4294),
#              ('fallen', 33),
#              ('off', 1287),
#              ('are', 6045),
#              ('aliens', 23),
#              ('likeunk', 1),
#              ('beth', 8),
#              ('she', 441),
#              ('haven', 45),
#              ('’', 2412),
#              ('t', 1242),
#              ('enough', 439),
#              ('gray', 11),
#              ('practically', 20),
#              ('france', 5),
#              ('greedy', 49),
#              ('45', 55),
#              ('what', 3084),
#              ('going', 1795),
#              ('finish', 164),
#              ('today', 1550),
#              ('ive', 1329),
#              ('commands', 26),
#              ('set', 278),
#              ('looking', 703),
#              ('forward', 388),
#              ('starting', 254),
#              ('about', 3517),
#              ('hour', 273),
#              ('start', 580),
#              ('an', 3284),
#              ('installed', 71),
#              ('events', 84),
#              ('look', 1051),
#              ('20', 731),
#              ('cleaning', 14),
#              ('just', 6658),
#              ('her', 814),
#              ('volume', 23),
#              ('awesome', 757),
#              ('server', 314),
#              ('imma', 77),
#              ('probably', 589),
#              ('play', 3413),
#              ('tps', 11),
#              ('thatll', 18),
#              ('playing', 2184),
#              ('its', 4309),
#              ('thatyer', 1),
#              ('ll', 113),
#              ('video', 1391),
#              ('own', 495),
#              ('profzeroo', 5),
#              ('w', 402),
#              ('3‼', 2),
#              ('him', 875),
#              ('buffly2wmmip5', 3),
#              ('say', 1091),
#              ('shouts', 17),
#              ('chat', 192),
#              ('chance', 460),
#              ('streamershouts', 2),
#              ('shout', 122),
#              ('buffly', 53),
#              ('2wmmip5', 3),
#              ('upcoming', 88),
#              ('profzero', 1),
#              ('p', 246),
#              ('–', 205),
#              ('also', 1529),
#              ('shows', 202),
#              ('via', 914),
#              ('at', 5373),
#              ('buff', 38),
#              ('ly', 139),
#              ('officially', 96),
#              ('series', 1294),
#              ('movies', 54),
#              ('invitation', 11),
#              ('invites', 3),
#              ('yessssssss', 3),
#              ('fick', 6),
#              ('yessssss', 2),
#              ('yessssssssunk', 1),
#              ('hate', 826),
#              ('easy', 260),
#              ('modifier', 11),
#              ('event', 375),
#              ('won’t', 130),
#              ('forever', 172),
#              ('most', 1529),
#              ('i’ve', 364),
#              ('game', 8052),
#              ('since', 919),
#              ('they', 3714),
#              ('added', 136),
#              ('them', 2018),
#              ('horrible', 124),
#              ('modifiers', 22),
#              ('please', 1968),
#              ('give', 800),
#              ('option', 136),
#              ('turn', 230),
#              ('pls', 213),
#              ('simple', 139),
#              ('chaos', 40),
#              ('wont', 490),
#              ('thats', 732),
#              ('terrible', 346),
#              ('saying', 340),
#              ('day', 1553),
#              ('9', 260),
#              ('ability', 51),
#              ('thinking', 221),
#              ('total', 141),
#              ('won', 556),
#              ('absolutely', 492),
#              ('ridiculous', 195),
#              ('ve', 225),
#              ('almost', 566),
#              ('do', 3565),
#              ('best', 2496),
#              ('taken', 317),
#              ('past', 260),
#              ('until', 567),
#              ('send', 135),
#              ('grounded', 5),
#              ('looked', 147),
#              ('pretty', 717),
#              ('cool', 714),
#              ('despite', 278),
#              ('tier', 73),
#              ('unfunny', 7),
#              ('writing', 76),
#              ('became', 97),
#              ('yet', 526),
#              ('another', 1043),
#              ('survival', 23),
#              ('crafting', 5),
#              ('can’t', 538),
#              ('shitty', 149),
#              ('trend', 38),
#              ('die', 350),
#              ('crappy', 45),
#              ('grosskreutz', 1),
#              ('spelling', 12),
#              ('turned', 138),
#              ('crap', 225),
#              ('mod', 39),
#              ('deep', 88),
#              ('fifth', 19),
#              ('format', 24),
#              ('ultimately', 14),
#              ('mobile', 499),
#              ('top', 731),
#              ('annoying', 275),
#              ('seriously', 314),
#              ('appreciate', 191),
#              ('sonic', 42),
#              ('concepts', 12),
#              ('praxis', 3),
#              ('valenzuela', 4),
#              ('landaposas', 3),
#              ('thread', 70),
#              ('together', 302),
#              ('talk', 302),
#              ('multimodal', 6),
#              ('listening', 92),
#              ('soundwalks', 5),
#              ('frameworks', 4),
#              ('participatory', 5),
#              ('action', 242),
#              ('research', 79),
#              ('testimonios', 4),
#              ('thoughtful', 5),
#              ('resonant', 6),
#              ('intersections', 6),
#              ('sound', 223),
#              ('practices', 6),
#              ('combine', 14),
#              ('lecture', 13),
#              ('testimonies', 1),
#              ('evaluate', 2),
#              ('valensela', 1),
#              ('landa', 2),
#              ('pozas', 1),
#              ('conversation', 36),
#              ('walks', 4),
#              ('areas', 24),
#              ('joint', 15),
#              ('studies', 23),
#              ('etc', 107),
#              ('amazing', 1291),
#              ('morenoposas', 1),
#              ('recordings', 8),
#              ('field', 44),
#              ('by', 2931),
#              ('electronic', 19),
#              ('posas', 1),
#              ('creating', 62),
#              ('visual', 21),
#              ('digital', 174),
#              ('interviews', 8),
#              ('thoughts', 59),
#              ('reflected', 3),
#              ('conversations', 18),
#              ('actions', 15),
#              ('klein', 1),
#              ('brought', 143),
#              ('experiences', 21),
#              ('ethical', 1),
#              ('provocative', 1),
#              ('submit', 34),
#              ('complaint', 28),
#              ('ceo', 47),
#              ('isnt', 191),
#              ('paying', 99),
#              ('his', 1247),
#              ('staff', 90),
#              ('bonuses', 20),
#              ('file', 86),
#              ('doesnt', 626),
#              ('pay', 487),
#              ('employees', 158),
#              ('competitors', 17),
#              ('suppose', 24),
#              ('isnain', 1),
#              ('entire', 292),
#              ('now', 4088),
#              ('any', 1180),
#              ('offering', 28),
#              ('fuckin', 135),
#              ('trash', 437),
#              ('damn', 1110),
#              ('rubbish', 21),
#              ('fucking', 2106),
#              ('thrash', 43),
#              ('shit', 2753),
#              ('35', 55),
#              ('played', 1159),
#              ('through', 730),
#              ('actual', 166),
#              ('great', 2246),
#              ('guns', 60),
#              ('feel', 718),
#              ('once', 363),
#              ('felt', 157),
#              ('needed', 127),
#              ('grind', 90),
#              ('story', 504),
#              ('other', 903),
#              ('hand', 147),
#              ('very', 1619),
#              ('eventual', 6),
#              ('cutscene', 19),
#              ('skip', 20),
#              ('weapons', 109),
#              ('funny', 324),
#              ('sequence', 8),
#              ('occasional', 4),
#              ('slip', 8),
#              ('open', 461),
#              ('someone', 758),
#              ('side', 195),
#              ('endless', 31),
#              ('5', 1652),
#              ('were', 1179),
#              ('sure', 551),
#              ('oh', 742),
#              ('yesm', 1),
#              ('extended', 27),
#              ('loving', 164),
#              ('ghostlifestyle', 4),
#              ('cans', 19),
#              ('anyone', 599),
#              ('drink', 26),
#              ('ghost', 267),
#              ('drinks', 9),
#              ('ghostlive', 1),
#              ('three', 278),
#              ('ghostlifestyleunk', 1),
#              ('want', 1508),
#              ('come', 966),
#              ('meet', 116),
#              ('lovely', 96),
#              ('gaming', 540),
#              ('goddesses', 5),
#              ('gambling', 30),
#              ('beautiful', 502),
#              ('gods', 52),
#              ('16', 142),
#              ('green', 87),
#              ('hell', 651),
#              ('halloween', 50),
#              ('month', 420),
#              ('already', 883),
#              ('march', 65),
#              ('pulling', 29),
#              ('bitch', 270),
#              ('slut', 14),
#              ('miracle', 26),
#              ('ok', 330),
#              ('bombs', 17),
#              ('over', 1732),
#              ('baghdad', 5),
#              ('anything', 530),
#              ('gets', 427),
#              ('hype', 109),
#              ('concept', 59),
#              ('a1', 10),
#              ('gives', 131),
#              ('baghad', 1),
#              ('seeing', 341),
#              ('take', 839),
#              ('sir', 104),
#              ('case', 147),
#              ('earth', 67),
#              ('rpg', 48),
#              ('uninstalled', 40),
#              ('games', 2284),
#              ('space', 113),
#              ('uninstall', 22),
#              ('room', 147),
#              ('deleted', 124),
#              ('watching', 412),
#              ('bleeding', 17),
#              ('edge', 136),
#              ('clever', 22),
#              ('cross', 96),
#              ('between', 231),
#              ('overwatch', 1367),
#              ('domination', 10),
#              ('mode', 425),
#              ('as', 3859),
#              ('crossroads', 1),
#              ('future', 195),
#              ('2016', 119),
#              ('fantasy', 121),
#              ('non', 56),
#              ('bioshock', 31),
#              ('switch', 279),
#              ('count', 73),
#              ('desert', 29),
#              ('montana', 1),
#              ('after', 1803),
#              ('platinum', 53),
#              ('loot', 124),
#              ('booty', 16),
#              ('lot', 725),
#              ('has', 3669),
#              ('named', 46),
#              ('reason', 422),
#              ('laptop', 100),
#              ('run', 415),
#              ('war', 748),
#              ('thunder', 30),
#              ('warframe', 10),
#              ('high', 327),
#              ('settings', 94),
#              ('moment', 203),
#              ('launch', 349),
#              ('csgo', 1198),
#              ('computer', 188),
#              ('crashes', 145),
#              ('whole', 550),
#              ('breaks', 33),
#              ('down', 1000),
#              ('firefox', 36),
#              ('plus', 191),
#              ('no', 3304),
#              ('easily', 87),
#              ('currently', 347),
#              ('dare', 45),
#              ('mind', 233),
#              ('software', 128),
#              ('mount', 47),
#              ('act', 95),
#              ('king', 120),
#              ('speeds', 54),
#              ('jumping', 66),
#              ('more', 3057),
#              ('dlcs', 19),
#              ('vibing', 4),
#              ('playlists', 16),
#              ('vibe', 46),
#              ('dropping', 74),
#              ('quality', 165),
#              ('720p', 5),
#              ('makes', 621),
#              ('difference', 73),
#              ('runs', 112),
#              ('dumb', 172),
#              ('internet', 482),
#              ('lmao', 283),
#              ('twitchtvheyitscece', 3),
#              ('streaming', 369),
#              ('vibrating', 1),
#              ('lowering', 5),
#              ('heyitscece', 1),
#              ('jon', 25),
#              ('downloading', 52),
#              ('tumb', 3),
#              ('enter', 113),
#              ('gunner', 14),
#              ('seat', 27),
#              ('fear', 88),
#              ('step', 248),
#              ('trench', 1),
#              ('then', 1401),
#              ('pictwittercomwav1bacr5j', 3),
#              ('wav1bacr5j', 2),
#              ('picwikipediaorg', 202),
#              ('v', 1005),
#              ('omg', 282),
#              ('ever', 1500),
#              ('thwarted', 4),
#              ('bank', 80),
#              ('foiled', 1),
#              ('threatened', 19),
#              ('who', 2173),
#              ('late', 207),
#              ('trip', 51),
#              ('seems', 379),
#              ('broken', 422),
#              ('with', 8860),
#              ('m10', 6),
#              ('rates', 18),
#              ('constantly', 113),
#              ('less', 278),
#              ('than', 1572),
#              ('lower', 93),
#              ('levels', 53),
#              ('possible', 185),
#              ('2500', 9),
#              ('swear', 121),
#              ('greens', 5),
#              ('blues', 24),
#              ('boss', 81),
#              ('falling', 63),
#              ('when', 3240),
#              ('rate', 91),
#              ('production', 88),
#              ('kinda', 300),
#              ('pushing', 54),
#              ('normal', 107),
#              ('people', 2878),
#              ('moving', 89),
#              ('recovery', 47),
#              ('fast', 182),
#              ('next', 1035),
#              ('gold', 283),
#              ('amounts', 12),
#              ('worked', 191),
#              ('onunk', 3),
#              ('cbp', 5),
#              ('dhswolf', 2),
#              ('deceptively', 5),
#              ('cut', 151),
#              ('parts', 45),
#              ('report', 209),
#              ('1⃣laikenjordahl', 1),
#              ('ripping', 10),
#              ('arizona', 7),
#              ('rest', 173),
#              ('two', 767),
#              ('2⃣usbp', 2),
#              ('admittedly', 6),
#              ('surveilling', 4),
#              ('us', 1869),
#              ('public', 116),
#              ('road', 81),
#              ('violent', 59),
#              ('clashes', 9),
#              ('indigenous', 4),
#              ('activists', 4),
#              ('protesting', 9),
#              ('wall', 118),
#              ('dhs', 3),
#              ('wolf', 21),
#              ('misleadingly', 1),
#              ('laikenjordahl', 1),
#              ('says', 458),
#              ('tearing', 23),
#              ('country', 136),
#              ('usbp', 1),
#              ('monitors', 9),
#              ('streets', 31),
#              ('against', 562),
#              ('cuts', 21),
#              ('somebody', 60),
#              ('bits', 21),
#              ('1⃣dhswolf', 1),
#              ('fatal', 7),
#              ('fact', 458),
#              ('before', 781),
#              ('began', 27),
#              ('american', 137),
#              ('protest', 4),
#              ('bp', 12),
#              ('taking', 279),
#              ('2usbp', 1),
#              ('photos', 84),
#              ('tucson', 6),
#              ('muslims', 2),
#              ('polycule', 4),
#              ('tonight', 496),
#              ('magical', 30),
#              ('evening', 88),
#              ('end', 480),
#              ('sigh', 35),
#              ('allowed', 58),
#              ('polyphony', 1),
#              ('polyslice', 1),
#              ('better', 888),
#              ('part', 560),
#              ('same', 913),
#              ('jackson', 50),
#              ('happy', 1185),
#              ('profitwise', 3),
#              ('expected', 93),
#              ('due', 403),
#              ('budget', 32),
#              ('profit', 38),
#              ('realize', 123),
#              ('because', 2140),
#              ('busted', 30),
#              ('wise', 22),
#              ('again', 1639),
#              ('only', 1922),
#              ('marketing', 86),
#              ('business', 409),
#              ('prior', 7),
#              ('problem', 578),
#              ('far', 484),
#              ('always', 1079),
#              ('fav', 63),
#              ('certainly', 108),
#              ('guardian', 33),
#              ('around', 537),
#              ('weekend', 305),
#              ('managed', 81),
#              ('done', 729),
#              ('enjoying', 151),
#              ('loved', 285),
#              ('slutty', 5),
#              ('mechanic', 34),
#              ('slutsky', 1),
#              ('old', 674),
#              ('night', 714),
#              ('heeps', 4),
#              ('closer', 32),
#              ('towards', 121),
#              ('raided', 24),
#              ('clocksydraws', 6),
#              ('art', 188),
#              ('pieces', 50),
#              ('follow', 317),
#              ('goodnight', 28),
#              ('loads', 46),
#              ('artwork', 26),
#              ('followup', 3),
#              ('havent', 267),
#              ('drove', 11),
#              ('street', 86),
#              ('works', 206),
#              ('let', 563),
#              ('imitate', 1),
#              ('dounk', 11),
#              ('re', 211),
#              ('brilliant', 100),
#              ('such', 873),
#              ('317slayer', 6),
#              ('drunkcookies', 4),
#              ('halo', 113),
#              ('23', 56),
#              ('pick', 166),
#              ('rocket', 38),
#              ('league', 1187),
#              ('kingdom', 53),
#              ('hearts', 45),
#              ('super', 691),
#              ('mario', 47),
#              ('bros', 12),
#              ('stars', 96),
#              ('demintelesway', 4),
#              ('discospider93', 5),
#              ('voidbwungus', 3),
#              ('lstesports', 3),
#              ('let’s', 57),
#              ('em', 57),
#              ('drunk', 40),
#              ('cookies', 14),
#              ('choose', 48),
#              ('demintele', 1),
#              ('sway', 11),
#              ('void', 23),
#              ('bwungus', 1),
#              ('lets', 433),
#              ('crises', 1),
#              ('floor', 20),
#              ('mainly', 45),
#              ('wars', 85),
#              ('playstation', 526),
#              ('s', 1556),
#              ('others', 177),
#              ('beat', 151),
#              ('express', 39),
#              ('literally', 618),
#              ('things', 664),
#              ('bl3', 30),
#              ('using', 494),
#              ('girl', 258),
#              ('fire', 218),
#              ('credits', 52),
#              ('i’m', 1106),
#              ('gonna', 751),
#              ('quit', 153),
#              ('leave', 271),
#              ('reminds', 43),
#              ('r', 270),
#              ('m', 623),
#              ('knows', 146),
#              ('yoooooooooo', 4),
#              ('hyped', 177),
#              ('movie', 267),
#              ('yooooooooooo', 1),
#              ('puffed', 2),
#              ('yooooooooo', 1),
#              ('guy', 613),
#              ('bc', 241),
#              ('those', 646),
#              ('okay', 206),
#              ('kind', 280),
#              ('bbc', 46),
#              ('region', 41),
#              ('think', 1292),
#              ('modern', 227),
#              ('warfare', 200),
#              ('38', 25),
#              ('deals', 106),
#              ('ps4', 453),
#              ('unsortedcomodernwarfare…', 2),
#              ('httpstco2n68qojkhu', 3),
#              ('unsortedco', 2),
#              ('modernwarfare', 2),
#              ('https', 712),
#              ('tco', 489),
#              ('2n68qojkhu', 1),
#              ('swift', 22),
#              ('unsorteco', 2),
#              ('gear', 63),
#              ('11', 161),
#              ('200', 104),
#              ('nintendo', 93),
#              ('group', 237),
#              ('unsorted', 2),
#              ('co', 170),
#              ('database', 16),
#              ('…', 1239),
#              ('online', 847),
#              ('compact', 3),
#              ('multi', 14),
#              ('nowcomodernwarfare', 1),
#              ('collection', 113),
#              ('youre', 488),
#              ('welcome', 250),
#              ('council', 5),
#              ('short', 167),
#              ('true', 228),
#              ('second', 356),
#              ('howre', 1),
#              ('disagree', 13),
#              ('psycho', 34),
#              ('krieg', 30),
#              ('fantastic', 238),
#              ('fustercluck', 19),
#              ('wonderful', 160),
#              ('line', 394),
#              ('focuses', 6),
#              ('character', 341),
#              ('lasting', 9),
#              ('players', 1040),
#              ('closure', 5),
#              ('questions', 67),
#              ('krieg’s', 1),
#              ('memorable', 19),
#              ('interact', 19),
#              ('conclusion', 13),
#              ('which', 919),
#              ('offers', 52),
#              ('longlasting', 1),
#              ('issues', 288),
#              ('ostik', 1),
#              ('fusterkluck', 1),
#              ('perfect', 409),
#              ('fans', 294),
#              ('opportunity', 100),
#              ('close', 210),
#              ('important', 167),
#              ('abouts', 1),
#              ('scenery', 11),
#              ('vs', 173),
#              ('primary', 16),
#              ('book', 219),
#              ('klaus', 1),
#              ('range', 21),
#              ('several', 135),
#              ('algorithm', 26),
#              ('alma', 1),
#              ('mater', 6),
#              ('april', 100),
#              ('patch', 279),
#              ('mini', 39),
#              ('difficulty', 51),
#              ('ramp', 8),
#              ('stats', 46),
#              ('fresh', 83),
#              ('extra', 123),
#              ('latest', 348),
#              ('ultimate', 157),
#              ('brand', 140),
#              ('level', 318),
#              ('power', 334),
#              ('upunk', 4),
#              ('optus', 6),
#              ('appears', 35),
#              ('accident', 26),
#              ('apology', 17),
#              ('apologies', 23),
#              ('idea', 343),
#              ('happened', 248),
#              ('hi', 286),
#              ('electricity', 4),
#              ('excuse', 70),
#              ('flow', 35),
#              ('lands', 19),
#              ('operator', 18),
#              ...])

# %%
sorted(word_counts.items(), key=lambda x: x[1], reverse=True)[:20]
# Out:
# [('the', 44419),
#  ('i', 29178),
#  ('to', 28825),
#  ('and', 26579),
#  ('a', 24095),
#  ('of', 19438),
#  ('is', 17823),
#  ('for', 15595),
#  ('in', 15385),
#  ('this', 14652),
#  ('it', 13775),
#  ('you', 12154),
#  ('on', 12050),
#  ('my', 11841),
#  ('that', 10227),
#  ('with', 8860),
#  ('game', 8052),
#  ('so', 7795),
#  ('me', 6988),
#  ('have', 6682)]

# %%
#ideal num words
import numpy as np

counts = np.array(list(word_counts.values()))
counts.sort()
counts = counts[::-1]

cumulative = np.cumsum(counts) / np.sum(counts)

np.where(cumulative >= 0.95)[0][0]
# Out:
# np.int64(12754)

# %% [markdown]
# We use num words as 12k

# %%
tokenizer=Tokenizer(num_words=12000,oov_token="OOV")

# %%
tokenizer.fit_on_texts(df['tweet'])

# %% [markdown]
# max len

# %%
lengths = [len(t.split()) for t in df["tweet"]]

import numpy as np
np.percentile(lengths, [90, 95, 99])
# Out:
# array([40., 47., 57.])

# %% [markdown]
# 95% of the tweet lengths are 57 so we round it up and make 60

# %%
sequences=tokenizer.texts_to_sequences(df['tweet'])

# %%
sequences=pad_sequences(sequences,maxlen=60,padding='post',truncating='post')

# %%
sequences
# Out:
# array([[  40,  161,   14, ...,    0,    0,    0],
#        [   3,  111,  395, ...,    0,    0,    0],
#        [  40,  161,   14, ...,    0,    0,    0],
#        ...,
#        [  22, 1902,    2, ...,    0,    0,    0],
#        [  22, 1902,  718, ...,    0,    0,    0],
#        [  22,   30,    2, ...,    0,    0,    0]],
#       shape=(73996, 60), dtype=int32)

# %%
X=sequences

# %%
y=df['sentiment']

# %%
X.shape
# Out:
# (73996, 60)

# %%
y.shape
# Out:
# (73996,)

# %%
y.value_counts()
# Out:
# sentiment
# Negative      22358
# Positive      20655
# Neutral       18108
# Irrelevant    12875
# Name: count, dtype: int64

# %%
label_map={
    'Negative':0,
    'Positive':1,
    'Neutral':2,
    'Irrelevant':3
}

# %%
y=df['sentiment'].map(label_map)

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 74677    1
# 74678    1
# 74679    1
# 74680    1
# 74681    1
# Name: sentiment, Length: 73996, dtype: int64

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: sentiment, dtype: int64

# %%
y.value_counts()
# Out:
# sentiment
# 0    22358
# 1    20655
# 2    18108
# 3    12875
# Name: count, dtype: int64

# %% [markdown]
# Model Building

# %%
from tensorflow.keras.layers import Bidirectional,Embedding,Dropout

# %%
model=Sequential()

# %%
model.add(Input(shape=(60,)))

# %%
model.add(Embedding(12000,128))

# %%
model.add(Bidirectional(LSTM(64)))

# %%
model.add(Dropout(0.5))

# %%
model.add(Dense(4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 60, 128)        │     1,536,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,635,332 (6.24 MB)
#  Trainable params: 1,635,332 (6.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 60, 128)        │     1,536,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,635,332 (6.24 MB)
#  Trainable params: 1,635,332 (6.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop=EarlyStopping(monitor="val_loss",patience=3,restore_best_weights=True)

# %%
history=model.fit(X,y,epochs=10,batch_size=64,validation_split=0.2,callbacks=[early_stop])
# Out:
# Epoch 1/10
# 925/925 ━━━━━━━━━━━━━━━━━━━━ 50s 51ms/step - accuracy: 0.6419 - loss: 0.8863 - val_accuracy: 0.4742 - val_loss: 1.4727
# Epoch 2/10
# 925/925 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.8287 - loss: 0.4701 - val_accuracy: 0.4832 - val_loss: 1.6475
# Epoch 3/10
# 925/925 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.8748 - loss: 0.3427 - val_accuracy: 0.4632 - val_loss: 2.0763
# Epoch 4/10
# 925/925 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.8999 - loss: 0.2728 - val_accuracy: 0.4588 - val_loss: 2.3067

# %%
model.save("model.keras")

# %%
import pickle

# %%
with open("tokenizer.pkl",'wb') as f:
    pickle.dump(tokenizer,f)
